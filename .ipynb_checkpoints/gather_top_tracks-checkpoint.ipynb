# %%
# Import Module
import requests
import json
import datetime
import pandas as pd

# %%
file_new = pd.read_json("raw/spotify/artist/top_tracks_Anirudh Ravichander_2025-12-04.json")

# %%
pd.json_normalize(file_new.tracks)
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit                                               href  \
# 0       217627     False  https://api.spotify.com/v1/tracks/7MrdHOL2aoWf...
# 1       197104     False  https://api.spotify.com/v1/tracks/28keFvZn4UVR...
# ...

# %%
pd.json_normalize(file_new.tracks).iloc[:,0:10]
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit                                               href  \
# 0       217627     False  https://api.spotify.com/v1/tracks/7MrdHOL2aoWf...
# 1       197104     False  https://api.spotify.com/v1/tracks/28keFvZn4UVR...
# ...

# %%
pd.json_normalize(file_new.tracks).iloc[:,11:20]
# Out:
#    track_number   type                                   uri album.album_type  \
# 0             5  track  spotify:track:7MrdHOL2aoWfT16CncgNei            album
# 1             1  track  spotify:track:28keFvZn4UVRi4I8Rj4GjY           single
# 2             7  track  spotify:track:3JC5Xx48KqzYYlbTr6weCv            album
# 3             2  track  spotify:track:3xMHXmedL5Rvfxmiar9Ryv            album
# 4             1  track  spotify:track:1bxzr3JK05fMTcweGAZUHp           single
# 5             5  track  spotify:track:7vKddq80IImHdiz83ZU2zF            album
# 6             1  track  spotify:track:4KUQFOGTaHrggl3hfMoaAe           single
# 7             1  track  spotify:track:3CA9CjRf7IU2Ukz3GuYInP            album
# 8             8  track  spotify:track:2unhBSPWS4Cpn5EfIKbAxG            album
# 9             1  track  spotify:track:07dj2zpMixBXxQuwp4erRD            album
#
#                                        album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# ...

# %%
pd.json_normalize(file_new.tracks).iloc[:,21:29]
# Out:
#                                         album.name album.release_date  \
# 0      Coolie (Original Motion Picture Soundtrack)         2025-08-02
# 1         Thalapathy Kacheri (From "Jana Nayagan")         2025-11-08
# 2      Coolie (Original Motion Picture Soundtrack)         2025-08-02
# 3                                            Jawan         2023-09-05
# 4               Chuttamalle (From "Devara Part 1")         2024-08-05
# 5      Coolie (Original Motion Picture Soundtrack)         2025-08-12
# 6  Kannamma (From "Ispade Rajavum Idhaya Raniyum")         2019-01-11
# 7   Vettaiyan (Original Motion Picture Soundtrack)         2024-10-14
# 8  Madharaasi (Original Motion Picture Soundtrack)         2025-08-27
# 9  Madharaasi (Original Motion Picture Soundtrack)         2025-08-27
#
#   album.release_date_precision  album.total_tracks album.type  \
# 0                          day                   8      album
# 1                          day                   1      album
# ...

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists[0])
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4zCH9qm4R2D...  4zCH9qm4R2DADamUHMCa6O
# 1  https://api.spotify.com/v1/artists/0nh5cRtt03S...  0nh5cRtt03SU6LhzhVC5fv
# 2  https://api.spotify.com/v1/artists/4b1WCDqAVVg...  4b1WCDqAVVgxK7KozLkOqc
#
#                   name    type                                    uri  \
# 0  Anirudh Ravichander  artist  spotify:artist:4zCH9qm4R2DADamUHMCa6O
# 1          Sublahshini  artist  spotify:artist:0nh5cRtt03SU6LhzhVC5fv
# 2          Asal Kolaar  artist  spotify:artist:4b1WCDqAVVgxK7KozLkOqc
#
#                                external_urls.spotify
# 0  https://open.spotify.com/artist/4zCH9qm4R2DADa...
# 1  https://open.spotify.com/artist/0nh5cRtt03SU6L...
# 2  https://open.spotify.com/artist/4b1WCDqAVVgxK7...

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists[1])
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4zCH9qm4R2D...  4zCH9qm4R2DADamUHMCa6O
# 1  https://api.spotify.com/v1/artists/0fhunuOz2Ou...  0fhunuOz2OuOEr3YK5ctSm
# 2  https://api.spotify.com/v1/artists/7rVV9d6vc4F...  7rVV9d6vc4FLT752uRuk71
#
#                   name    type                                    uri  \
# 0  Anirudh Ravichander  artist  spotify:artist:4zCH9qm4R2DADamUHMCa6O
# 1     Thalapathy Vijay  artist  spotify:artist:0fhunuOz2OuOEr3YK5ctSm
# 2                Arivu  artist  spotify:artist:7rVV9d6vc4FLT752uRuk71
#
#                                external_urls.spotify
# 0  https://open.spotify.com/artist/4zCH9qm4R2DADa...
# 1  https://open.spotify.com/artist/0fhunuOz2OuOEr...
# 2  https://open.spotify.com/artist/7rVV9d6vc4FLT7...

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists[2])
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4zCH9qm4R2D...  4zCH9qm4R2DADamUHMCa6O
# 1  https://api.spotify.com/v1/artists/7rVV9d6vc4F...  7rVV9d6vc4FLT752uRuk71
#
#                   name    type                                    uri  \
# 0  Anirudh Ravichander  artist  spotify:artist:4zCH9qm4R2DADamUHMCa6O
# 1                Arivu  artist  spotify:artist:7rVV9d6vc4FLT752uRuk71
#
#                                external_urls.spotify
# 0  https://open.spotify.com/artist/4zCH9qm4R2DADa...
# 1  https://open.spotify.com/artist/7rVV9d6vc4FLT7...

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists)[0][0]
# Out:
# {'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#  'id': '4zCH9qm4R2DADamUHMCa6O',
#  'name': 'Anirudh Ravichander',
#  'type': 'artist',
#  'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O',
#  'external_urls.spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists)[0][1]
# Out:
# {'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#  'id': '4zCH9qm4R2DADamUHMCa6O',
#  'name': 'Anirudh Ravichander',
#  'type': 'artist',
#  'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O',
#  'external_urls.spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists)[1][0]
# Out:
# {'href': 'https://api.spotify.com/v1/artists/0nh5cRtt03SU6LhzhVC5fv',
#  'id': '0nh5cRtt03SU6LhzhVC5fv',
#  'name': 'Sublahshini',
#  'type': 'artist',
#  'uri': 'spotify:artist:0nh5cRtt03SU6LhzhVC5fv',
#  'external_urls.spotify': 'https://open.spotify.com/artist/0nh5cRtt03SU6LhzhVC5fv'}

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists)[2][0]
# Out:
# {'href': 'https://api.spotify.com/v1/artists/4b1WCDqAVVgxK7KozLkOqc',
#  'id': '4b1WCDqAVVgxK7KozLkOqc',
#  'name': 'Asal Kolaar',
#  'type': 'artist',
#  'uri': 'spotify:artist:4b1WCDqAVVgxK7KozLkOqc',
#  'external_urls.spotify': 'https://open.spotify.com/artist/4b1WCDqAVVgxK7KozLkOqc'}

# %%
file_new = pd.read_json("raw/spotify/artist/top_tracks_Billie_Eilish_2025-12-15.json")

# %%
pd.json_normalize(file_new.tracks)
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit                                               href  \
# 0       210373     False  https://api.spotify.com/v1/tracks/6dOtVTDdiauQ...
# 1       261466     False  https://api.spotify.com/v1/tracks/3QaPy1KgI7nu...
# ...

# %%
pd.json_normalize(pd.json_normalize(file_new.tracks).artists[0][0]).name
# Out:
# 0    Billie Eilish
# Name: name, dtype: object
